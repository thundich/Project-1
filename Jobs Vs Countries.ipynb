# %%
#Dependencies:
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load Data:
country_df = pd.read_csv("../Project-1/salaries.csv")
country_df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT  Machine Learning Engineer
# 1          2023               MI              FT          Research Engineer
# 2          2023               MI              FT          Research Engineer
# 3          2023               MI              FT          Research Engineer
# 4          2023               MI              FT          Research Engineer
# ...         ...              ...             ...                        ...
# 8123       2020               SE              FT             Data Scientist
# 8124       2021               MI              FT   Principal Data Scientist
# 8125       2020               EN              FT             Data Scientist
# 8126       2020               EN              CT      Business Data Analyst
# 8127       2021               SE              FT       Data Science Manager
#
# ...

# %%
#Data info
country_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           8128 non-null   int64
#  1   experience_level    8128 non-null   object
#  2   employment_type     8128 non-null   object
#  3   job_title           8128 non-null   object
#  4   salary              8128 non-null   int64
#  5   salary_currency     8128 non-null   object
#  6   salary_in_usd       8128 non-null   int64
#  7   employee_residence  8128 non-null   object
#  8   remote_ratio        8128 non-null   int64
#  9   company_location    8128 non-null   object
#  10  company_size        8128 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 698.6+ KB

# %%
country = country_df["company_location"].unique()
country
# Out:
# array(['US', 'CO', 'UA', 'SI', 'IN', 'GB', 'RO', 'ES', 'CA', 'GR', 'PT',
#        'FR', 'NL', 'LV', 'MU', 'DE', 'PL', 'RU', 'IT', 'KR', 'EE', 'CZ',
#        'CH', 'BR', 'QA', 'KE', 'DK', 'GH', 'SE', 'PH', 'AU', 'TR', 'AD',
#        'EC', 'MX', 'IL', 'NG', 'SA', 'NO', 'AR', 'JP', 'ZA', 'HK', 'CF',
#        'FI', 'IE', 'SG', 'TH', 'HR', 'AM', 'BA', 'PK', 'LT', 'IR', 'BS',
#        'HU', 'AT', 'PR', 'AS', 'BE', 'ID', 'EG', 'AE', 'MY', 'HN', 'DZ',
#        'IQ', 'CN', 'NZ', 'CL', 'MD', 'LU', 'MT'], dtype=object)

# %%
Countries = len(country)
Countries
# Out:
# 73

# %%
Job = country_df["job_title"].unique()
print(Job)
# Out:
# ['Machine Learning Engineer' 'Research Engineer' 'Data Analyst'
#  'Applied Scientist' 'Data Scientist' 'ML Engineer' 'Data Engineer'
#  'AI Developer' 'BI Developer' 'Research Scientist' 'AI Programmer'
#  'Data Lead' 'Data Product Manager' 'Decision Scientist'
#  'Data Science Consultant' 'Financial Data Analyst' 'AI Engineer'
#  'Business Intelligence Engineer' 'Data Architect'
#  'Business Intelligence Analyst' 'Data Quality Analyst' 'Research Analyst'
#  'Data Science Engineer' 'Analytics Engineer' 'Data Strategy Manager'
#  'Data Manager' 'Machine Learning Scientist' 'Computer Vision Engineer'
#  'Data Visualization Specialist' 'Data Science Manager' 'BI Analyst'
#  'Insight Analyst' 'Data Integration Specialist'
#  'Data Science Practitioner' 'Director of Data Science' 'Data Specialist'
#  'Data Visualization Engineer' 'Data Modeler' 'Head of Data'
#  'ETL Developer' 'Data Analytics Manager' 'Azure Data Engineer'
#  'Machine Learning Infrastructure Engineer' 'Data Developer'
# ...

# %%
Jobs = len(Job)
Jobs
# Out:
# 119

# %%
country_df.groupby('job_title').company_location.count().sort_values(ascending=False)[:10].plot.bar()

plt.title("Job Title Vs Number of Jobs")
plt.xlabel("Job Title")
plt.ylabel("Number of Jobs")

plt.savefig('Title Vs Jobs.png', transparent=True)
plt.show()

# %%
y_axis = country_df["job_title"]
x_axis = country_df["company_location"]
plt.figure(figsize = (15,12))

plt.title("Company Location Vs Job Titles")
plt.bar(x_axis, y_axis,linewidth=2, color = "c")
plt.xticks(x_axis, rotation = "vertical")
plt.xlabel("Company Location")
plt.ylabel("Job Title")

plt.savefig("Location Vs Title.png", transparent=True)
plt.show()

# %%
country_df.groupby('company_location').job_title.count().sort_values(ascending=False)[:10].plot.bar()

plt.title("Company Location Vs Number of Jobs")
plt.xlabel("Company Location")
plt.ylabel("Number of Jobs")
plt.show()
plt.savefig('Company Location Vs Jobs.png', transparent=True)

# %% [markdown]
# US=United States
# GB=Great Britain
# CA=Canada
# ES=Spain
# DE=Germany
# IN=India
# FR=France
# AU=Australia
# PT=Portugal
# NL=Netherlands

# %%
Job_type = country_df["employment_type"].unique()
Job_type
# Out:
# array(['FT', 'CT', 'PT', 'FL'], dtype=object)

# %% [markdown]
# FT = Full-time
# CT = Contract
# PT = Part-time
# FL = Freelance

# %%
remote = country_df["remote_ratio"].unique()
remote
# Out:
# array([100,   0,  50])

# %% [markdown]
# 100 = Fully remote work (more that 80%
# 50 = Partially remote/Hybrid
# 0 = No remote work (less than 20%)

# %%
remote = country_df[country_df['remote_ratio'] == '100']
job_type = country_df.groupby('employment_type').remote_ratio.count()
job_type
# Out:
# employment_type
# CT      18
# FL      11
# FT    8086
# PT      13
# Name: remote_ratio, dtype: int64

# %%
remote = [18,11,8086,13]
types = ['CT', 'FL', 'FT', 'PT']
colors = ["red", "yellow", "blue","green"]
explode = (0.1,0,0,0)

plt.pie(remote, explode=explode, labels=types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.savefig('Remote vs Employment Type.png', transparent=True)
plt.show()

# %%
us_df = country_df[country_df['company_location']=='US']
remote = country_df[country_df['remote_ratio'] == '100']
remote_us = us_df.groupby("employment_type").remote_ratio.count()
remote_us
# Out:
# employment_type
# CT      13
# FL       4
# FT    6935
# PT       4
# Name: remote_ratio, dtype: int64

# %%
remote = [13,4,6935,4]
types = ['CT', 'FL', 'FT', 'PT']
colors = ["blue", "yellow", "red","green"]
explode = (0.1,0,0,0)

plt.pie(remote, explode=explode, labels=types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.savefig('Remote(US) vs Employment Type.png', transparent=True)
plt.show()
